# %%
a=5
b=6
print(a*b)
# Out:
# 30

# %%
a=int(input())
if (a>=18):
    print("person is eligible")
else:
    print("person not eligible")
# Out:
# 19
# person is eligible

# %%
x=200
y=100
if x>y:
  print("x is greaterthen y")
else:
  print("y is not greaterthen x ")
# Out:
# x is greaterthen y

# %%
a = int(input('enter a number :- '))
b = int(input('enter a number :- '))
print(a+b)
# Out:
# enter a number :- 30
# enter a number :- 100
# 130

# %%
a=int(input())
x=10
y=30
z=50
if(x>y and x>Z):
    print("x")
elif(y>z):
    print(y)
else:
    print(z)
# Out:
# 40
# 50

# %%
a=int(input())
if (a>0):
  print("postive number")
elif (a<0):
    print("negitive number")
else:
  print("0")
# Out:
# -4
# negitive number

# %%
a=int(input("366 is a leap year"))
if(a==366):
  print("a is leap year")
elif(a>366):
  print("a is  not leap year")
elif(a<366):
  print("a is not leap year")
else:
  print("leap year")
